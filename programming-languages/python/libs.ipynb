# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
a = np.array([[1,2],[3,4]])

# %%
b = np.matrix([[1,2],[3,4]])

# %%
a @ b
# Out:
# matrix([[ 7, 10],
#         [15, 22]])

# %%
np.arange(1,19,3)
# Out:
# array([ 1,  4,  7, 10, 13, 16])

# %%
my_series = pd.Series([1,2,3,4,5], index =['row1','row2','row3','row4','row5'] )

# %%
my_series
# Out:
# row1    1
# row2    2
# row3    3
# row4    4
# row5    5
# dtype: int64

# %%
my_array = np.array([[1,5,9,13],[2,6,10,14],[3,7,11,15],[4,8,12,16]])

# %%
my_df = pd.DataFrame(my_array, index = ['row1','row2','row3','row4'],columns = ['col1','col2','col3','col4'])

# %%
my_df
# Out:
#       col1  col2  col3  col4
# row1     1     5     9    13
# row2     2     6    10    14
# row3     3     7    11    15
# row4     4     8    12    16

# %%
years = [1960,1970,1980,1990,2000,2010,2020]
iran_pop = [ 21.31,28.51,38.67,56.23,66.13,74.57,80.28]

# %%
plt.hist(years,iran_pop)
plt.show()
