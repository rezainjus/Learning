# %% [raw]
# داده کاوی = استخراج الگو های مورد نظر از حجم زیاد داده ها

# %% [raw]
# انواع الگوریتم های یادگیری
# ۱. یادگیری با ناظر
# ۲. یادگیری بدون ناظر
# ۳. یادگیری نیمه نظارتی
# ۴. یادگیری تفویتی

# %% [raw]
# یادگیری با ناظر --> می توان به ماشین پاسخ درست را برای چند نمونه محدود از ورودی ها بدهیم به این امید که بتواند آن را برای نمونه های دیگر تعمیم کند.

# %% [raw]
# یادگیری با ناظر در دو حالت ۱. رگرسیون و ۲.دسته بندی وجود دارد

# %% [raw]
# رگرسیون:
# نتیجه گیری با استفاده از داده بصورت عددی پیوسته

# %% [raw]
# دسته بندی:
# نتیجه گیری شرطی (بله یا خیر) با استفاده از داده های موجود
# یا برچسب گذاری
